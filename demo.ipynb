# %%
from sam_onnx import InferSAM

# %%
IS = InferSAM(model_name='l0')
IS.set_figsize(figsize=(6,8))
# Out:
# loading encoder model from D:\Work\work\SAM_ONNX\SAM_ONNX\model_weights\l0\encoder.onnx...
# loading decoder model from D:\Work\work\SAM_ONNX\SAM_ONNX\model_weights\l0\decoder.onnx...

# %%
msk = IS.infer(img_path=r'tests/images/test2.jpg',
              boxes=[[55,99,455,794],
                     [467,49,866,822]],  # format = [[x1,y1,x2,y2],[x1,y1,x2,y2], ...]
              visualize=True)

# %%
msk = IS.infer(img_path=r'tests/images/test1.jpg',
              boxes=[[238,48,649,569]],  # format = [[x1,y1,x2,y2]]
              visualize=True)
